# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#To ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\program files\python38\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\program files\python38\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Data Set

# %%
file1=pd.read_excel('D:/program session/project/Energy/file2011.xlsx')
file2=pd.read_excel('D:/program session/project/Energy/file2012.xlsx')
file3=pd.read_excel('D:/program session/project/Energy/file2013.xlsx')
file4=pd.read_excel('D:/program session/project/Energy/file2014.xlsx')
file5=pd.read_excel('D:/program session/project/Energy/file2015.xlsx')
file6=pd.read_excel('D:/program session/project/Energy/file2016.xlsx')
file7=pd.read_excel('D:/program session/project/Energy/file2017.xlsx')
file8=pd.read_excel('D:/program session/project/Energy/file2018.xlsx')
file9=pd.read_excel('D:/program session/project/Energy/file2019.xlsx')
file10=pd.read_excel('D:/program session/project/Energy/file2020.xlsx')
file11=pd.read_excel('D:/program session/project/Energy/file2021.xlsx')

# %% [markdown]
# # Merge the Data Set

# %%
file1.head(2)
# Out:
#   Sector Name SubSector Name Organization Name    Operation Name  \
# 0   Municipal   Municipality  Town of Goderich  Municipal Office
# 1   Municipal   Municipality  Town of Goderich  Goderich Library
#
#                                       Operation Type             Address  \
# 0  Administrative offices and related facilities,...      57 West Street
# 1                                   Public libraries  52 Montreal Street
#
#        City Postal Code  Total Floor Area          Unit1  ...  Unit10  \
# 0  Goderich     N7A 2K5           21510.0    Square feet  ...     NaN
# 1  Goderich     N7A 2K5            1100.0  Square meters  ...     NaN
#
#    Renewable2  Emission Factor2 Swimming Pool  Number of Portables  \
# 0         0.0               NaN           0.0                  NaN
# 1         0.0               NaN           0.0                  NaN
#
#   GHG Emissions(Kg)  Energy Intensity ekWh_sqft  \
# 0      24740.490790                   11.650264
# 1      45163.116457                   25.237567
#
#   Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2  \
# 0                              NaN                0.451449
# 1                              NaN                0.977989
#
#   Energy Intensity GJ_mega_litre
# 0                            NaN
# 1                            NaN
#
# [2 rows x 41 columns]

# %%
pd.set_option('display.max_columns',None)
file1.head(2)
# Out:
#   Sector Name SubSector Name Organization Name    Operation Name  \
# 0   Municipal   Municipality  Town of Goderich  Municipal Office
# 1   Municipal   Municipality  Town of Goderich  Goderich Library
#
#                                       Operation Type             Address  \
# 0  Administrative offices and related facilities,...      57 West Street
# 1                                   Public libraries  52 Montreal Street
#
#        City Postal Code  Total Floor Area          Unit1  Annual Flow  \
# 0  Goderich     N7A 2K5           21510.0    Square feet          NaN
# 1  Goderich     N7A 2K5            1100.0  Square meters          NaN
#
#    Average Hours Per Week  Electricity Unit2  Natural Gas        Unit3  \
# 0                    40.0     248444.0   kWh        202.6  Cubic meter
# 1                    62.0     100147.0   kWh      18694.7  Cubic meter
#
#    Fuel Oil 1 & 2 Unit4  Fuel Oil 4 & 6 Unit5  Propane Unit6  Coal Unit7  \
# 0             NaN   NaN             NaN   NaN      NaN   NaN   NaN   NaN
# 1             NaN   NaN             NaN   NaN      NaN   NaN   NaN   NaN
#
#    Wood Unit8  District Heat Unit9  Renewable1  Emission Factor1  \
# 0   NaN   NaN            NaN   NaN         0.0               NaN
# 1   NaN   NaN            NaN   NaN         0.0               NaN
#
#    District Cool Unit10  Renewable2  Emission Factor2  Swimming Pool  \
# 0            NaN    NaN         0.0               NaN            0.0
# 1            NaN    NaN         0.0               NaN            0.0
#
#    Number of Portables  GHG Emissions(Kg)  Energy Intensity ekWh_sqft  \
# 0                  NaN       24740.490790                   11.650264
# 1                  NaN       45163.116457                   25.237567
#
#    Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2  \
# 0                               NaN                0.451449
# 1                               NaN                0.977989
#
#    Energy Intensity GJ_mega_litre
# 0                             NaN
# 1                             NaN

# %%
column_name_mapping = {
    'Sector Name': 'Sector',
    'SubSector Name': 'SubSector',
    'Organization Name' : 'Organization',
    'Operation Name':'Operation',
    'Average Hours Per Week':'Weekly Average Hours',
    'Total Floor Area':'Total Indoor Space_x',
    'Unit1':'Unit of Measure',
    'Annual Flow':'Annual Flow (M)',
    'Electricity':'Electricity_Quantity',
    'Unit2':'Electricity_Unit',
    'Natural Gas':'NaturalGas_Quantity',
    'Unit3':'NaturalGas_Unit',
    'Fuel Oil 1 & 2':'FuelOil12_Quantity',
    'Unit4':'FuelOil12_Unit',
    'Fuel Oil 4 & 6':'FuelOil46_Quantity',
    'Unit5':'FuelOil46_Unit',
    'Propane':'Propane_Quantity',
    'Unit6':'Propane_Unit',
    'Coal':'Coal_Quantity',
    'Unit7':'Coal_Unit',
    'Wood':'Wood_Quantity',
    'Unit8':'Wood_Unit',
    'District Heat':'DistrictHeating_Quantity',
    'Unit9':'DistrictHeating_Unit',
    'Renewable1':'DistrictHeating_IsRenewable',
    'Emission Factor1':'DistrictHeating_RenewableEmissionFactor',
    'District Cool':'DistrictCooling_Quantity',
    'Unit10':'DistrictCooling_Unit',
    'Renewable2':'DistrictCooling_IsRenewable',
    'Emission Factor2':'DistrictCooling_RenewableEmissionFactor',
    'GHG Emissions(Kg)':'GHG Emissions KG',
    
}

# %%
file1 = file1.rename(columns=column_name_mapping)

# %%
file1.columns
# Out:
# Index(['Sector', 'SubSector', 'Organization', 'Operation', 'Operation Type',
#        'Address', 'City', 'Postal Code', 'Total Indoor Space_x',
#        'Unit of Measure', 'Annual Flow (M)', 'Weekly Average Hours',
#        'Electricity_Quantity', 'Electricity_Unit', 'NaturalGas_Quantity',
#        'NaturalGas_Unit', 'FuelOil12_Quantity', 'FuelOil12_Unit',
#        'FuelOil46_Quantity', 'FuelOil46_Unit', 'Propane_Quantity',
#        'Propane_Unit', 'Coal_Quantity', 'Coal_Unit', 'Wood_Quantity',
#        'Wood_Unit', 'DistrictHeating_Quantity', 'DistrictHeating_Unit',
#        'DistrictHeating_IsRenewable',
#        'DistrictHeating_RenewableEmissionFactor', 'DistrictCooling_Quantity',
#        'DistrictCooling_Unit', 'DistrictCooling_IsRenewable',
#        'DistrictCooling_RenewableEmissionFactor', 'Swimming Pool',
#        'Number of Portables', 'GHG Emissions KG', 'Energy Intensity ekWh_sqft',
#        'Energy Intensity ekWh_mega_litre', 'Energy Intensity GJ_m2',
#        'Energy Intensity GJ_mega_litre'],
#       dtype='object')

# %%
column_name_mapping = {
    'Sector Name': 'Sector',
    'Sub Sector ': 'SubSector',
    'Organization Name' : 'Organization',
    'Operation Name':'Operation',
    'Average Hours per week':'Weekly Average Hours',
    'Total Floor Area ':'Total Indoor Space_x',
    'Unit':'Unit of Measure',
    'Annual Flow ':'Annual Flow (M)',
    'Electricity':'Electricity_Quantity',
    'Electricity Unit':'Electricity_Unit',
    'Natural Gas':'NaturalGas_Quantity',
    'Natural Gas2':'NaturalGas_Unit',
    'Fuel Oil 1 & 2':'FuelOil12_Quantity',
    'Fuel Oil 1 & 2 Unit':'FuelOil12_Unit',
    'Fuel Oil 4 &6':'FuelOil46_Quantity',
    'Fuel Oil 4 &6 Unit':'FuelOil46_Unit',
    'Propane':'Propane_Quantity',
    'Propane Unit':'Propane_Unit',
    'Coal Quantity':'Coal_Quantity',
    'Coal Unit':'Coal_Unit',
    'Wood':'Wood_Quantity',
    'Wood3':'Wood_Unit',
    'District Heating':'DistrictHeating_Quantity',
    'District Heating Unit':'DistrictHeating_Unit',
    'Renewable':'DistrictHeating_IsRenewable',
    'Renewable Emission Factor':'DistrictHeating_RenewableEmissionFactor',
    'District Cooling':'DistrictCooling_Quantity',
    'District Cooling Unit':'DistrictCooling_Unit',
    'District Cooling Renewable':'DistrictCooling_IsRenewable',
    'District Cooling Renewable Emission Factor':'DistrictCooling_RenewableEmissionFactor',
    'GHG Emissions(Kg)':'GHG Emissions KG',
    'Swimming Pools':'Swimming Pool'
}

# %%
file2 = file2.rename(columns=column_name_mapping)

# %%
file2.columns
# Out:
# Index(['Sector', 'SubSector', 'Organization', 'Operation', 'Operation Type',
#        'Address', 'City', 'Postal Code', 'Total Indoor Space_x',
#        'Unit of Measure', 'Weekly Average Hours', 'Annual Flow (M)',
#        'Electricity_Quantity', 'Electricity_Unit', 'NaturalGas_Quantity',
#        'NaturalGas_Unit', 'FuelOil12_Quantity', 'FuelOil12_Unit',
#        'FuelOil46_Quantity', 'FuelOil46_Unit', 'Propane_Quantity',
#        'Propane_Unit', 'Coal_Quantity', 'Coal_Unit', 'Wood_Quantity',
#        'Wood_Unit', 'DistrictHeating_Quantity', 'DistrictHeating_Unit',
#        'DistrictHeating_IsRenewable',
#        'DistrictHeating_RenewableEmissionFactor', 'DistrictCooling_Quantity',
#        'DistrictCooling_Unit', 'DistrictCooling_IsRenewable',
#        'DistrictCooling_RenewableEmissionFactor', 'Number of Portables',
#        'Swimming Pool', 'GHG Emissions KG', 'Energy Intensity ekWh_sqft',
#        'Energy Intensity ekWh_mega_litre', 'Energy Intensity GJ_m2',
#        'Energy Intensity GJ_mega_litre'],
#       dtype='object')

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file3 = file3.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file4 = file4.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file5 = file5.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file6 = file6.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file7 = file7.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file8 = file8.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file9 = file9.rename(columns=column_name_mapping)

# %%
df = pd.concat([file1, file10,file9,file8,file7,file6,file5,file4,file3,file2], ignore_index=True)
pd.set_option('display.max_columns',None)
df
# Out:
#                                         Sector     SubSector  \
# 0                                    Municipal  Municipality
# 1                                    Municipal  Municipality
# 2                                    Municipal  Municipality
# 3                                    Municipal  Municipality
# 4                                    Municipal  Municipality
# ...                                        ...           ...
# 173835  Post-secondary Educational Institution   University
# 173836  Post-secondary Educational Institution   University
# 173837  Post-secondary Educational Institution   University
# 173838  Post-secondary Educational Institution   University
# 173839  Post-secondary Educational Institution   University
#
#             Organization                                       Operation  \
# 0       Town of Goderich                                Municipal Office
# 1       Town of Goderich                                Goderich Library
# 2       Town of Goderich                           Water Treatment Plant
# 3       Town of Goderich                                   Elevated Tank
# 4       Town of Goderich                  Reservoir-Booster Pump Station
# ...                  ...                                             ...
# 173835   York University  William Small Centre - PS2 Face Building (398)
# 173836   York University                           Winters College (368)
# 173837   York University                                 York Hall (304)
# 173838   York University                          York Lanes (383) (450)
# 173839   York University                 York University Bookstore (203)
#
#                                            Operation Type  \
# 0       Administrative offices and related facilities,...
# 1                                        Public libraries
# 2            Facilities related to the treatment of water
# 3              Facilities related to the pumping of water
# 4              Facilities related to the pumping of water
# ...                                                   ...
# 173835      Administrative offices and related facilities
# 173836      Administrative offices and related facilities
# 173837      Administrative offices and related facilities
# 173838      Administrative offices and related facilities
# 173839      Administrative offices and related facilities
#
#                     Address      City Postal Code  Total Indoor Space_x  \
# 0            57 West Street  Goderich     N7A 2K5              21510.00
# 1        52 Montreal Street  Goderich     N7A 2K5               1100.00
# 2               100 Cove Rd  Goderich     N7A 2K5                733.00
# 3       220 St David Street  Goderich     N7A 2K5                 63.00
# 4         371 Parsons Court  Goderich     N7A 2K5                184.00
# ...                     ...       ...         ...                   ...
# 173835    4700 Keele Street   Toronto      M3J1P3               4812.49
# 173836    4700 Keele Street   Toronto      M3J1P3               6897.26
# 173837  2275 Bayview Avenue   Toronto      M4N3M6              19992.81
# 173838    4700 Keele Street   Toronto      M3J1P3              10533.75
# 173839    4700 Keele Street   Toronto      M3J1P3               2482.49
#
#        Unit of Measure  Annual Flow (M)  Weekly Average Hours  \
# 0          Square feet              NaN                  40.0
# 1        Square meters              NaN                  62.0
# 2        Square meters         1405.631                 168.0
# 3        Square meters            1.000                 168.0
# 4        Square meters            1.000                 168.0
# ...                ...              ...                   ...
# 173835   Square meters            0.000                  61.0
# 173836   Square meters            0.000                  85.0
# 173837   Square meters            0.000                 112.0
# 173838   Square meters            0.000                 133.0
# 173839   Square meters            0.000                  50.0
#
#         Electricity_Quantity Electricity_Unit  NaturalGas_Quantity  \
# 0                   248444.0              kWh                202.6
# 1                   100147.0              kWh              18694.7
# 2                   994783.0              kWh                  NaN
# 3                    15519.0              kWh                  NaN
# 4                   123972.0              kWh                  NaN
# ...                      ...              ...                  ...
# 173835             1898435.0              kWh                  0.0
# 173836             1585386.0              kWh                  0.0
# 173837             1829015.0              kWh                  0.0
# 173838               90990.0              kWh             244044.0
# 173839              548509.0              kWh                  0.0
#
#        NaturalGas_Unit  FuelOil12_Quantity FuelOil12_Unit  FuelOil46_Quantity  \
# 0          Cubic meter                 NaN            NaN                 NaN
# 1          Cubic meter                 NaN            NaN                 NaN
# 2                  NaN                 NaN            NaN                 NaN
# 3                  NaN                 NaN            NaN                 NaN
# 4                  NaN                 NaN            NaN                 NaN
# ...                ...                 ...            ...                 ...
# 173835     Cubic Meter                 0.0          Litre                 0.0
# 173836     Cubic Meter                 0.0          Litre                 0.0
# 173837     Cubic Meter                 0.0          Litre                 0.0
# 173838     Cubic Meter                 0.0          Litre                 0.0
# 173839     Cubic Meter                 0.0          Litre                 0.0
#
#        FuelOil46_Unit  Propane_Quantity Propane_Unit Coal_Quantity  \
# 0                 NaN               NaN          NaN           NaN
# 1                 NaN               NaN          NaN           NaN
# 2                 NaN               NaN          NaN           NaN
# 3                 NaN               NaN          NaN           NaN
# 4                 NaN               NaN          NaN           NaN
# ...               ...               ...          ...           ...
# 173835          Litre               0.0        Litre           0.0
# 173836          Litre               0.0        Litre           0.0
# 173837          Litre               0.0        Litre           0.0
# 173838          Litre               0.0        Litre           0.0
# 173839          Litre               0.0        Litre           0.0
#
#            Coal_Unit  Wood_Quantity     Wood_Unit  DistrictHeating_Quantity  \
# 0                NaN            NaN           NaN                       NaN
# 1                NaN            NaN           NaN                       NaN
# 2                NaN            NaN           NaN                       NaN
# 3                NaN            NaN           NaN                       NaN
# 4                NaN            NaN           NaN                       NaN
# ...              ...            ...           ...                       ...
# 173835  Metric Tonne            0.0  Metric Tonne                  4580.683
# 173836  Metric Tonne            0.0  Metric Tonne                 17026.690
# 173837  Metric Tonne            0.0  Metric Tonne                 14146.560
# 173838  Metric Tonne            0.0  Metric Tonne                     0.000
# 173839  Metric Tonne            0.0  Metric Tonne                     0.000
#
#        DistrictHeating_Unit DistrictHeating_IsRenewable  \
# 0                       NaN                         0.0
# 1                       NaN                         0.0
# 2                       NaN                         0.0
# 3                       NaN                         0.0
# 4                       NaN                         0.0
# ...                     ...                         ...
# 173835           Giga Joule                       False
# 173836           Giga Joule                       False
# 173837           Giga Joule                       False
# 173838           Giga Joule                       False
# 173839           Giga Joule                       False
#
#         DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
# ...                                         ...                       ...
# 173835                                      0.0                  1910.829
# 173836                                      0.0                  2374.588
# 173837                                      0.0                     0.000
# 173838                                      0.0                  4050.645
# 173839                                      0.0                  1377.224
#
#        DistrictCooling_Unit DistrictCooling_IsRenewable  \
# 0                       NaN                         0.0
# 1                       NaN                         0.0
# 2                       NaN                         0.0
# 3                       NaN                         0.0
# 4                       NaN                         0.0
# ...                     ...                         ...
# 173835           Giga Joule                       False
# 173836           Giga Joule                       False
# 173837           Giga Joule                       False
# 173838           Giga Joule                       False
# 173839           Giga Joule                       False
#
#         DistrictCooling_RenewableEmissionFactor Swimming Pool  \
# 0                                           NaN           0.0
# 1                                           NaN           0.0
# 2                                           NaN           0.0
# 3                                           NaN           0.0
# 4                                           NaN           0.0
# ...                                         ...           ...
# 173835                                      0.0         False
# 173836                                      0.0         False
# 173837                                      0.0         False
# 173838                                      0.0         False
# 173839                                      0.0         False
#
#         Number of Portables  GHG Emissions KG  Energy Intensity ekWh_sqft  \
# 0                       NaN      2.474049e+04                   11.650264
# 1                       NaN      4.516312e+04                   25.237567
# 2                       NaN      9.752853e+04                  126.078258
# 3                       NaN      1.521483e+03                   22.884372
# 4                       NaN      1.215421e+04                   62.592400
# ...                     ...               ...                         ...
# 173835                  0.0      4.693998e+05                   64.316827
# 173836                  0.0      1.181111e+06                   87.752824
# 173837                  0.0      1.014525e+06                   26.759251
# 173838                  0.0      5.028809e+05                   26.684434
# 173839                  0.0      6.381251e+04                   24.865427
#
#         Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2  \
# 0                                    NaN                0.451449
# 1                                    NaN                0.977989
# 2                             707.712764                4.885701
# 3                           15519.000000                0.886800
# 4                          123972.000000                2.425539
# ...                                  ...                     ...
# 173835                          0.000000                2.492283
# 173836                          0.000000                3.400430
# 173837                          0.000000                1.036923
# 173838                          0.000000                1.034024
# 173839                          0.000000                0.963538
#
#         Energy Intensity GJ_mega_litre
# 0                                  NaN
# 1                                  NaN
# 2                             2.547766
# 3                            55.868400
# 4                           446.299196
# ...                                ...
# 173835                        0.000000
# 173836                        0.000000
# 173837                        0.000000
# 173838                        0.000000
# 173839                        0.000000
#
# [173840 rows x 41 columns]

# %% [markdown]
# # DATA Cleaning

# %% [markdown]
# ## Handiling Missing Value

# %%
df.isnull().sum()
# Out:
# Sector                                          0
# SubSector                                       5
# Organization                                    0
# Operation                                       0
# Operation Type                                  0
# Address                                       105
# City                                            1
# Postal Code                                   175
# Total Indoor Space_x                         3105
# Unit of Measure                              9913
# Annual Flow (M)                             25024
# Weekly Average Hours                         4391
# Electricity_Quantity                          264
# Electricity_Unit                             2689
# NaturalGas_Quantity                          5708
# NaturalGas_Unit                             51760
# FuelOil12_Quantity                          14455
# FuelOil12_Unit                             146075
# FuelOil46_Quantity                          15190
# FuelOil46_Unit                             151262
# Propane_Quantity                            14571
# Propane_Unit                               144194
# Coal_Quantity                               15260
# Coal_Unit                                  151717
# Wood_Quantity                               15255
# Wood_Unit                                  151665
# DistrictHeating_Quantity                    15094
# DistrictHeating_Unit                       150343
# DistrictHeating_IsRenewable                135988
# DistrictHeating_RenewableEmissionFactor     36560
# DistrictCooling_Quantity                    15145
# DistrictCooling_Unit                       150753
# DistrictCooling_IsRenewable                136378
# DistrictCooling_RenewableEmissionFactor     36471
# Swimming Pool                               79272
# Number of Portables                         16516
# GHG Emissions KG                               33
# Energy Intensity ekWh_sqft                   3279
# Energy Intensity ekWh_mega_litre            15651
# Energy Intensity GJ_m2                       8223
# Energy Intensity GJ_mega_litre              16239
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['float64']).columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

int_columns = df.select_dtypes(include=['int64']).columns
df[int_columns] = df[int_columns].fillna(df[int_columns].mean())

# categorical columns (using mode)
categorical_columns = df.select_dtypes(include=['object']).columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Sector                                     0
# SubSector                                  0
# Organization                               0
# Operation                                  0
# Operation Type                             0
# Address                                    0
# City                                       0
# Postal Code                                0
# Total Indoor Space_x                       0
# Unit of Measure                            0
# Annual Flow (M)                            0
# Weekly Average Hours                       0
# Electricity_Quantity                       0
# Electricity_Unit                           0
# NaturalGas_Quantity                        0
# NaturalGas_Unit                            0
# FuelOil12_Quantity                         0
# FuelOil12_Unit                             0
# FuelOil46_Quantity                         0
# FuelOil46_Unit                             0
# Propane_Quantity                           0
# Propane_Unit                               0
# Coal_Quantity                              0
# Coal_Unit                                  0
# Wood_Quantity                              0
# Wood_Unit                                  0
# DistrictHeating_Quantity                   0
# DistrictHeating_Unit                       0
# DistrictHeating_IsRenewable                0
# DistrictHeating_RenewableEmissionFactor    0
# DistrictCooling_Quantity                   0
# DistrictCooling_Unit                       0
# DistrictCooling_IsRenewable                0
# DistrictCooling_RenewableEmissionFactor    0
# Swimming Pool                              0
# Number of Portables                        0
# GHG Emissions KG                           0
# Energy Intensity ekWh_sqft                 0
# Energy Intensity ekWh_mega_litre           0
# Energy Intensity GJ_m2                     0
# Energy Intensity GJ_mega_litre             0
# dtype: int64

# %% [markdown]
# ## Wrong Formate

# %%
df.dtypes
# Out:
# Sector                                      object
# SubSector                                   object
# Organization                                object
# Operation                                   object
# Operation Type                              object
# Address                                     object
# City                                        object
# Postal Code                                 object
# Total Indoor Space_x                       float64
# Unit of Measure                             object
# Annual Flow (M)                            float64
# Weekly Average Hours                       float64
# Electricity_Quantity                       float64
# Electricity_Unit                            object
# NaturalGas_Quantity                        float64
# NaturalGas_Unit                             object
# FuelOil12_Quantity                         float64
# FuelOil12_Unit                              object
# FuelOil46_Quantity                         float64
# FuelOil46_Unit                              object
# Propane_Quantity                           float64
# Propane_Unit                                object
# Coal_Quantity                               object
# Coal_Unit                                   object
# Wood_Quantity                              float64
# Wood_Unit                                   object
# DistrictHeating_Quantity                   float64
# DistrictHeating_Unit                        object
# DistrictHeating_IsRenewable                 object
# DistrictHeating_RenewableEmissionFactor    float64
# DistrictCooling_Quantity                   float64
# DistrictCooling_Unit                        object
# DistrictCooling_IsRenewable                 object
# DistrictCooling_RenewableEmissionFactor    float64
# Swimming Pool                               object
# Number of Portables                        float64
# GHG Emissions KG                           float64
# Energy Intensity ekWh_sqft                 float64
# Energy Intensity ekWh_mega_litre           float64
# Energy Intensity GJ_m2                     float64
# Energy Intensity GJ_mega_litre             float64
# dtype: object

# %%
df.head(2)
# Out:
#       Sector     SubSector      Organization         Operation  \
# 0  Municipal  Municipality  Town of Goderich  Municipal Office
# 1  Municipal  Municipality  Town of Goderich  Goderich Library
#
#                                       Operation Type             Address  \
# 0  Administrative offices and related facilities,...      57 West Street
# 1                                   Public libraries  52 Montreal Street
#
#        City Postal Code  Total Indoor Space_x Unit of Measure  \
# 0  Goderich     N7A 2K5               21510.0     Square feet
# 1  Goderich     N7A 2K5                1100.0   Square meters
#
#    Annual Flow (M)  Weekly Average Hours  Electricity_Quantity  \
# 0     56673.778915                  40.0              248444.0
# 1     56673.778915                  62.0              100147.0
#
#   Electricity_Unit  NaturalGas_Quantity NaturalGas_Unit  FuelOil12_Quantity  \
# 0              kWh                202.6     Cubic meter        2.101072e+06
# 1              kWh              18694.7     Cubic meter        2.101072e+06
#
#   FuelOil12_Unit  FuelOil46_Quantity FuelOil46_Unit  Propane_Quantity  \
# 0          Litre       377120.760397          Litre        862.785831
# 1          Litre       377120.760397          Litre        862.785831
#
#   Propane_Unit Coal_Quantity     Coal_Unit  Wood_Quantity     Wood_Unit  \
# 0        Litre           0.0  Metric Tonne       1.804703  Metric Tonne
# 1        Litre           0.0  Metric Tonne       1.804703  Metric Tonne
#
#    DistrictHeating_Quantity DistrictHeating_Unit DistrictHeating_IsRenewable  \
# 0               1471.943076           Giga Joule                         0.0
# 1               1471.943076           Giga Joule                         0.0
#
#    DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                 0.040603                 37.282138
# 1                                 0.040603                 37.282138
#
#   DistrictCooling_Unit DistrictCooling_IsRenewable  \
# 0           Giga Joule                         0.0
# 1           Giga Joule                         0.0
#
#    DistrictCooling_RenewableEmissionFactor Swimming Pool  Number of Portables  \
# 0                                 0.005159           0.0             0.504207
# 1                                 0.005159           0.0             0.504207
#
#    GHG Emissions KG  Energy Intensity ekWh_sqft  \
# 0      24740.490790                   11.650264
# 1      45163.116457                   25.237567
#
#    Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2  \
# 0                      8.320059e+13                0.451449
# 1                      8.320059e+13                0.977989
#
#    Energy Intensity GJ_mega_litre
# 0                    3.006396e+11
# 1                    3.006396e+11

# %%
df['Coal_Quantity'].value_counts()
# Out:
# Coal_Quantity
# 0.000000        173823
# 2275.306889          2
# 2.000000             1
# 1.000000             1
# 19590.631690         1
# 24624.183486         1
# 21765.514522         1
# 23445.292610         1
# 14950.748546         1
# 15121.331040         1
# 33559.881622         1
# 12704.211504         1
# 4304.752764          1
# Name: count, dtype: int64

# %%
df['Swimming Pool'].describe()
# Out:
# count     173840
# unique         6
# top           No
# freq      136334
# Name: Swimming Pool, dtype: object

# %%
df['Coal_Quantity'] = pd.to_numeric(df['Coal_Quantity'], errors='coerce')

# %%
df['Coal_Quantity'].dtypes
# Out:
# dtype('float64')

# %%
df['DistrictHeating_IsRenewable'].value_counts()
# Out:
# DistrictHeating_IsRenewable
# 0.0    172613
# 1.0        21
# Name: count, dtype: int64

# %%
df['DistrictCooling_IsRenewable'].value_counts()
# Out:
# DistrictCooling_IsRenewable
# 0.0    172978
# 1.0        16
# Name: count, dtype: int64

# %%
df['DistrictHeating_IsRenewable'] = pd.to_numeric(df['DistrictHeating_IsRenewable'], errors='coerce')
df['DistrictCooling_IsRenewable'] = pd.to_numeric(df['DistrictCooling_IsRenewable'], errors='coerce')

# %%
df['DistrictHeating_IsRenewable'].dtypes
df['DistrictCooling_IsRenewable'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Text Errors

# %%
object_data_cols = [var for var in df.columns if df[var].dtype == 'object']
object_data_cols
# Out:
# ['Sector',
#  'SubSector',
#  'Organization',
#  'Operation',
#  'Operation Type',
#  'Address',
#  'City',
#  'Postal Code',
#  'Unit of Measure',
#  'Electricity_Unit',
#  'NaturalGas_Unit',
#  'FuelOil12_Unit',
#  'FuelOil46_Unit',
#  'Propane_Unit',
#  'Coal_Unit',
#  'Wood_Unit',
#  'DistrictHeating_Unit',
#  'DistrictCooling_Unit',
#  'Swimming Pool']

# %%
df['Sector'].value_counts()
# Out:
# Sector
# Municipal                                 100810
# School Board                               49684
# Municipality                               10805
# Post-Secondary Educational Institution      8367
# Hospital                                    4174
# Name: count, dtype: int64

# %%
df['Sector'] = df['Sector'].replace({
                                    'Post-secondary Educational Institution':'Post-Secondary Educational Institution',
                                    'Public Hospital':'Hospital',
                                    
                                            })

# %%
df['SubSector'].value_counts()
# Out:
# SubSector
# Municipality               110997
# School Board                49664
# College                      5981
# Acute/Chronic Hospital       2496
# University                   2262
# Acute/Chronic                 821
# Municipal Service Board       601
# Acute Hospital                416
# Chronic Hospital              250
# University                    126
# Acute                         114
# Chronic                        50
# Township                       30
# School Boards                  20
# college                         8
# Municipal                       4
# Name: count, dtype: int64

# %%
df['SubSector'] = df['SubSector'].replace({'Acute Hospital':'Acute/Chronic Hospital',
                                           'Chronic Hospital':'Acute/Chronic Hospital',
                                           'Acute/Chronic':'Acute/Chronic Hospital',
                                           'Acute':'Acute/Chronic Hospital',
                                           'Chronic':'Acute/Chronic Hospital',
                                           'University ':'University',
                                           'college':'College',
                                           'School Boards':'School Board',
                                           'Municipal':'Municipal Service Board',
                                           })

# %%
df['Organization'].value_counts()
# Out:
# Organization
# City of Toronto                              11751
# Toronto District School Board                 5705
# Peel District School Board                    2630
# City of Greater Sudbury                       2572
# City of Ottawa                                2416
#                                              ...
# Township of Moonbeam                             6
# Elliot Lake St. Joseph's General Hospital        6
# Town of Latchford                                5
# Brant Caommunity Healthcare System               5
# Windsor Hotel-Dieu Grace Hospital                2
# Name: count, Length: 744, dtype: int64

# %%
df['Organization'].value_counts()
# Out:
# Operation
# Municipal Office               648
# Water Treatment Plant          513
# Fire Hall                      501
# Public Works Garage            387
# Town Hall                      331
#                               ...
# Malibu PS                        1
# Leamington Mall PS               1
# Golfwood PS                      1
# Erie St S PS                     1
# Hotel-Dieu Grace Healthcare      1
# Name: count, Length: 27385, dtype: int64

# %%
df['Organization'].value_counts()
# Out:
# Organization
# City of Toronto                              11751
# Toronto District School Board                 5705
# Peel District School Board                    2630
# City of Greater Sudbury                       2572
# City of Ottawa                                2416
#                                              ...
# Township of Moonbeam                             6
# Elliot Lake St. Joseph's General Hospital        6
# Town of Latchford                                5
# Brant Caommunity Healthcare System               5
# Windsor Hotel-Dieu Grace Hospital                2
# Name: count, Length: 744, dtype: int64

# %%
df['Operation Type'].value_counts()
# Out:
# Operation Type
# School                                                                                 42580
# Storage facilities where equipment or vehicles are maintained, repaired or stored      13054
# Administrative offices and related facilities, including municipal council chambers    12567
# Fire stations and associated offices and facilities                                    11473
# Other                                                                                  10744
#                                                                                        ...
# Administrative/Maintenance/Facilities                                                      1
# Leased area - not owned by Board                                                           1
# Vacant                                                                                     1
# Parking Lot                                                                                1
# Office                                                                                     1
# Name: count, Length: 86, dtype: int64

# %%
df['Unit of Measure'].value_counts()
# Out:
# Unit of Measure
# Square feet      129477
# Square meters     38989
# Square Feet        4574
# pieds carrés        324
# square feet         265
# mètres carrés       154
# Pieds carrés         47
# square meters         5
# Square Meters         2
# x                     1
# Sq Ft                 1
# Mètres carrés         1
# Name: count, dtype: int64

# %%
df['Unit of Measure'] = df['Unit of Measure'].replace({'Sq Ft':'Square Feet',
                                                       'x':'Square Feet',
                                                       'Square feet':'Square Feet',
                                                       'square feet':'Square Feet',
                                                       'Square meters':'Square Meters',
                                                       'square meters':'Square Meters',
                                                       'mètres carrés':'Mètres carrés',
                                                       'Mètres carrés':'Metres Carres',
                                                       'pieds carrés':'Pieds carrés',
                                                       'Pieds carrés':'Pieds Carres'
                                           })

# %%
df['Electricity_Unit'].value_counts()
# Out:
# Electricity_Unit
# kWh    173820
# kwh        16
# KWh         3
# x           1
# Name: count, dtype: int64

# %%
df['Electricity_Unit'] = df['Electricity_Unit'].replace({'kWh':'KWh',
                                                         'kwh':'KWh',
                                                         'x':'KWh'
                                                       
                                           })

# %%
df['NaturalGas_Unit'].value_counts()
# Out:
# NaturalGas_Unit
# Cubic Meter    159923
# Cubic meter     13243
# ekWh              323
# Giga Joule        243
# mètre cube         97
# cubic meter         9
# Litre               1
# x                   1
# Name: count, dtype: int64

# %%
df['NaturalGas_Unit'] = df['NaturalGas_Unit'].replace({'Cubic meter':'Cubic Meter',
                                                       'cubic meter':'Cubic Meter',
                                                       'mètre cube':'Cubic Meter',
                                                       'x':'ekWh',
                                                       'Litre':'ekWh',
                                                       'ekwh':'ekWh'
                                           })

# %%
df['FuelOil12_Unit'].value_counts()
# Out:
# FuelOil12_Unit
# Litre     173828
# Litres         7
# litre          5
# Name: count, dtype: int64

# %%
df['FuelOil12_Unit'] = df['FuelOil12_Unit'].replace({'Litres':'Litre',
                                                         'litre':'Litre',})

# %%
df['FuelOil46_Unit'].value_counts()
# Out:
# FuelOil46_Unit
# Litre    173840
# Name: count, dtype: int64

# %%
df['Propane_Unit'].value_counts()
# Out:
# Propane_Unit
# Litre        173825
# litre             8
# Litres            3
# 125544.62         1
# 36052.69          1
# 123351.09         1
# 18181.02          1
# Name: count, dtype: int64

# %%
df['Propane_Unit'] = df['Propane_Unit'].replace({
    125544.62: 'Litre',
    36052.69: 'Litre',
    123351.09: 'Litre',
    18181.02: 'Litre'})

# %%
df['Coal_Unit'].value_counts()
# Out:
# Coal_Unit
# Metric Tonne      169696
# Metric tonne        4097
# Tonne métrique        47
# Name: count, dtype: int64

# %%
df['Coal_Unit'] = df['Coal_Unit'].replace({'Metric tonne':'Metric Tonne',
                                                         'Tonne métrique':'Metric Tonne',})

# %%
df['Wood_Unit'].value_counts()
# Out:
# Wood_Unit
# Metric Tonne      169689
# Metric tonne        4104
# Tonne métrique        47
# Name: count, dtype: int64

# %%
df['Wood_Unit'] = df['Wood_Unit'].replace({'Metric tonne':'Metric Tonne',
                                                         'Tonne métrique':'Metric Tonne',})

# %%
df['DistrictHeating_Unit'].value_counts()
# Out:
# DistrictHeating_Unit
# Giga Joule                          169411
# Giga Joule - steam or hot water       4244
# Metric Tonne                           115
# Gigajoule - vapeur ou eau chaude        47
# metric tonne - steam                    17
# kilolitre - hot water                    5
# KL Hot Water                             1
# Name: count, dtype: int64

# %%
df['DistrictHeating_Unit'] = df['DistrictHeating_Unit'].replace({'Giga Joule - steam or hot water':'Giga Joule',
                                                       'Gigajoule - vapeur ou eau chaude':'Giga Joule',
                                                       'metric tonne - steam':'Metric Tonne',
                                                       'kilolitre - hot water':'kilolitre',
                                                       'KL Hot Water':'kilolitre', })

# %%
df['DistrictCooling_Unit'].value_counts()
# Out:
# DistrictCooling_Unit
# Giga Joule                    169516
# Giga Joule - chilled water      4210
# KL Chilled Water                  61
# Gigajoule                         47
# kilolitre - chilled water          6
# Name: count, dtype: int64

# %%
df['DistrictCooling_Unit'] = df['DistrictCooling_Unit'].replace({'Giga Joule - chilled water':'Giga Joule',
                                                       'Gigajoule':'Giga Joule',
                                                       'kilolitre - chilled water':'kilolitre',
                                                       'KL Chilled Water':'kilolitre', })

# %%
df['Swimming Pool'].value_counts()
# Out:
# Swimming Pool
# No      136334
# 0.0      36424
# Yes        724
# 1.0        192
# non        101
# S.O.        65
# Name: count, dtype: int64

# %%
df['Swimming Pool'] = df['Swimming Pool'].replace({1.0:'Yes',
                                                       0.0:'non',
                                                       'S.O.':'Yes',
                                                        })

# %%
df['Swimming Pool'].value_counts()
# Out:
# Swimming Pool
# No     136334
# non     36525
# Yes       981
# Name: count, dtype: int64

# %% [markdown]
# # Covert_CSV

# %%
df.to_csv('D:/program session/project/Energy/final.csv')

# %%
df=pd.read_csv('D:/program session/project/Energy/final.csv')
df
# Out:
#         Unnamed: 0                                  Sector     SubSector  \
# 0                0                               Municipal  Municipality
# 1                1                               Municipal  Municipality
# 2                2                               Municipal  Municipality
# 3                3                               Municipal  Municipality
# 4                4                               Municipal  Municipality
# ...            ...                                     ...           ...
# 173835      173835  Post-Secondary Educational Institution    University
# 173836      173836  Post-Secondary Educational Institution    University
# 173837      173837  Post-Secondary Educational Institution    University
# 173838      173838  Post-Secondary Educational Institution    University
# 173839      173839  Post-Secondary Educational Institution    University
#
#             Organization                                       Operation  \
# 0       Town of Goderich                                Municipal Office
# 1       Town of Goderich                                Goderich Library
# 2       Town of Goderich                           Water Treatment Plant
# 3       Town of Goderich                                   Elevated Tank
# 4       Town of Goderich                  Reservoir-Booster Pump Station
# ...                  ...                                             ...
# 173835   York University  William Small Centre - PS2 Face Building (398)
# 173836   York University                           Winters College (368)
# 173837   York University                                 York Hall (304)
# 173838   York University                          York Lanes (383) (450)
# 173839   York University                 York University Bookstore (203)
#
#                                            Operation Type  \
# 0       Administrative offices and related facilities,...
# 1                                        Public libraries
# 2            Facilities related to the treatment of water
# 3              Facilities related to the pumping of water
# 4              Facilities related to the pumping of water
# ...                                                   ...
# 173835      Administrative offices and related facilities
# 173836      Administrative offices and related facilities
# 173837      Administrative offices and related facilities
# 173838      Administrative offices and related facilities
# 173839      Administrative offices and related facilities
#
#                     Address      City Postal Code  Total Indoor Space_x  \
# 0            57 West Street  Goderich     N7A 2K5              21510.00
# 1        52 Montreal Street  Goderich     N7A 2K5               1100.00
# 2               100 Cove Rd  Goderich     N7A 2K5                733.00
# 3       220 St David Street  Goderich     N7A 2K5                 63.00
# 4         371 Parsons Court  Goderich     N7A 2K5                184.00
# ...                     ...       ...         ...                   ...
# 173835    4700 Keele Street   Toronto      M3J1P3               4812.49
# 173836    4700 Keele Street   Toronto      M3J1P3               6897.26
# 173837  2275 Bayview Avenue   Toronto      M4N3M6              19992.81
# 173838    4700 Keele Street   Toronto      M3J1P3              10533.75
# 173839    4700 Keele Street   Toronto      M3J1P3               2482.49
#
#        Unit of Measure  Annual Flow (M)  Weekly Average Hours  \
# 0          Square Feet     56673.778915                  40.0
# 1        Square Meters     56673.778915                  62.0
# 2        Square Meters      1405.631000                 168.0
# 3        Square Meters         1.000000                 168.0
# 4        Square Meters         1.000000                 168.0
# ...                ...              ...                   ...
# 173835   Square Meters         0.000000                  61.0
# 173836   Square Meters         0.000000                  85.0
# 173837   Square Meters         0.000000                 112.0
# 173838   Square Meters         0.000000                 133.0
# 173839   Square Meters         0.000000                  50.0
#
#         Electricity_Quantity Electricity_Unit  NaturalGas_Quantity  \
# 0                   248444.0              KWh           202.600000
# 1                   100147.0              KWh         18694.700000
# 2                   994783.0              KWh        421855.810603
# 3                    15519.0              KWh        421855.810603
# 4                   123972.0              KWh        421855.810603
# ...                      ...              ...                  ...
# 173835             1898435.0              KWh             0.000000
# 173836             1585386.0              KWh             0.000000
# 173837             1829015.0              KWh             0.000000
# 173838               90990.0              KWh        244044.000000
# 173839              548509.0              KWh             0.000000
#
#        NaturalGas_Unit  FuelOil12_Quantity FuelOil12_Unit  FuelOil46_Quantity  \
# 0          Cubic Meter        2.101072e+06          Litre       377120.760397
# 1          Cubic Meter        2.101072e+06          Litre       377120.760397
# 2          Cubic Meter        2.101072e+06          Litre       377120.760397
# 3          Cubic Meter        2.101072e+06          Litre       377120.760397
# 4          Cubic Meter        2.101072e+06          Litre       377120.760397
# ...                ...                 ...            ...                 ...
# 173835     Cubic Meter        0.000000e+00          Litre            0.000000
# 173836     Cubic Meter        0.000000e+00          Litre            0.000000
# 173837     Cubic Meter        0.000000e+00          Litre            0.000000
# 173838     Cubic Meter        0.000000e+00          Litre            0.000000
# 173839     Cubic Meter        0.000000e+00          Litre            0.000000
#
#        FuelOil46_Unit  Propane_Quantity Propane_Unit  Coal_Quantity  \
# 0               Litre        862.785831        Litre            0.0
# 1               Litre        862.785831        Litre            0.0
# 2               Litre        862.785831        Litre            0.0
# 3               Litre        862.785831        Litre            0.0
# 4               Litre        862.785831        Litre            0.0
# ...               ...               ...          ...            ...
# 173835          Litre          0.000000        Litre            0.0
# 173836          Litre          0.000000        Litre            0.0
# 173837          Litre          0.000000        Litre            0.0
# 173838          Litre          0.000000        Litre            0.0
# 173839          Litre          0.000000        Litre            0.0
#
#            Coal_Unit  Wood_Quantity     Wood_Unit  DistrictHeating_Quantity  \
# 0       Metric Tonne       1.804703  Metric Tonne               1471.943076
# 1       Metric Tonne       1.804703  Metric Tonne               1471.943076
# 2       Metric Tonne       1.804703  Metric Tonne               1471.943076
# 3       Metric Tonne       1.804703  Metric Tonne               1471.943076
# 4       Metric Tonne       1.804703  Metric Tonne               1471.943076
# ...              ...            ...           ...                       ...
# 173835  Metric Tonne       0.000000  Metric Tonne               4580.683000
# 173836  Metric Tonne       0.000000  Metric Tonne              17026.690000
# 173837  Metric Tonne       0.000000  Metric Tonne              14146.560000
# 173838  Metric Tonne       0.000000  Metric Tonne                  0.000000
# 173839  Metric Tonne       0.000000  Metric Tonne                  0.000000
#
#        DistrictHeating_Unit  DistrictHeating_IsRenewable  \
# 0                Giga Joule                          0.0
# 1                Giga Joule                          0.0
# 2                Giga Joule                          0.0
# 3                Giga Joule                          0.0
# 4                Giga Joule                          0.0
# ...                     ...                          ...
# 173835           Giga Joule                          0.0
# 173836           Giga Joule                          0.0
# 173837           Giga Joule                          0.0
# 173838           Giga Joule                          0.0
# 173839           Giga Joule                          0.0
#
#         DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                      0.040603                 37.282138
# 1                                      0.040603                 37.282138
# 2                                      0.040603                 37.282138
# 3                                      0.040603                 37.282138
# 4                                      0.040603                 37.282138
# ...                                         ...                       ...
# 173835                                 0.000000               1910.829000
# 173836                                 0.000000               2374.588000
# 173837                                 0.000000                  0.000000
# 173838                                 0.000000               4050.645000
# 173839                                 0.000000               1377.224000
#
#        DistrictCooling_Unit  DistrictCooling_IsRenewable  \
# 0                Giga Joule                          0.0
# 1                Giga Joule                          0.0
# 2                Giga Joule                          0.0
# 3                Giga Joule                          0.0
# 4                Giga Joule                          0.0
# ...                     ...                          ...
# 173835           Giga Joule                          0.0
# 173836           Giga Joule                          0.0
# 173837           Giga Joule                          0.0
# 173838           Giga Joule                          0.0
# 173839           Giga Joule                          0.0
#
#         DistrictCooling_RenewableEmissionFactor Swimming Pool  \
# 0                                      0.005159           non
# 1                                      0.005159           non
# 2                                      0.005159           non
# 3                                      0.005159           non
# 4                                      0.005159           non
# ...                                         ...           ...
# 173835                                 0.000000           non
# 173836                                 0.000000           non
# 173837                                 0.000000           non
# 173838                                 0.000000           non
# 173839                                 0.000000           non
#
#         Number of Portables  GHG Emissions KG  Energy Intensity ekWh_sqft  \
# 0                  0.504207      2.474049e+04                   11.650264
# 1                  0.504207      4.516312e+04                   25.237567
# 2                  0.504207      9.752853e+04                  126.078258
# 3                  0.504207      1.521483e+03                   22.884372
# 4                  0.504207      1.215421e+04                   62.592400
# ...                     ...               ...                         ...
# 173835             0.000000      4.693998e+05                   64.316827
# 173836             0.000000      1.181111e+06                   87.752824
# 173837             0.000000      1.014525e+06                   26.759251
# 173838             0.000000      5.028809e+05                   26.684434
# 173839             0.000000      6.381251e+04                   24.865427
#
#         Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2  \
# 0                           8.320059e+13                0.451449
# 1                           8.320059e+13                0.977989
# 2                           7.077128e+02                4.885701
# 3                           1.551900e+04                0.886800
# 4                           1.239720e+05                2.425539
# ...                                  ...                     ...
# 173835                      0.000000e+00                2.492283
# 173836                      0.000000e+00                3.400430
# 173837                      0.000000e+00                1.036923
# 173838                      0.000000e+00                1.034024
# 173839                      0.000000e+00                0.963538
#
#         Energy Intensity GJ_mega_litre
# 0                         3.006396e+11
# 1                         3.006396e+11
# 2                         2.547766e+00
# 3                         5.586840e+01
# 4                         4.462992e+02
# ...                                ...
# 173835                    0.000000e+00
# 173836                    0.000000e+00
# 173837                    0.000000e+00
# 173838                    0.000000e+00
# 173839                    0.000000e+00
#
# [173840 rows x 42 columns]
